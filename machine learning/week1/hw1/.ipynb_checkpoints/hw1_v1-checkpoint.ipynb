# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import deque

class TreeNode():
    left = None
    right = None
    attribute = None
    splitter = None
    depth = None
    examples = None
    label = None
    flag = None
    def __init__(self,depth,examples):
        self.depth = depth
        self.examples = examples

class DecisionTree():
    max_depth = 0
    tree = None
    def __init__(self,max_depth):
        self.max_depth = max_depth

    def fit(self,X,y):
        if len(X)!=len(y):
            print("Length does not match")
            return
        #replace NAN with most common value of the column
        X.apply(lambda x: x.fillna(x.value_counts().idxmax()),axis=0)
        self.tree = treeGenerator(X,y,0,self.max_depth)
        return self

    def predict(self,T):
        curr = self.tree
        y_predicted = []
        for i in range(0,len(T)):
            while curr.label==None:
                if T.iloc[i][curr.attribute]<curr.splitter:
                    curr = curr.left
                else:
                    curr = curr.right
            y_predicted.append(curr.label)
        return y_predicted

    def printTree(self):
        queue = deque([self.tree])
        while queue:
            curr = queue.popleft()
            print("depth: "+str(curr.depth))
            if curr.label:
                print("type: leaf")
                print("class: "+str(curr.label))
            else:
                print("type: internal")
            if curr.attribute:
                print("column "+str(curr.attribute)+"<"+str(curr.splitter)+"?")
            if curr.left:
                queue.append(curr.left)
            if curr.right:
                queue.append(curr.right)

#grow tree that fits the training set
def treeGenerator(X,y,depth,max_depth):
    if len(set(y))==1 or depth==max_depth:
        leaf = TreeNode(depth,X)
        leaf.label = y.value_counts().idxmax() ##the most common value in y
        return leaf
    else:
        root = TreeNode(depth,X)
        X_left,X_right,root.attribute,root.splitter = findBestSplit(X,y)
        y_left = y[X_left.index]
        y_right = y[X_right.index]
        root.left = treeGenerator(X_left,y_left,depth+1,max_depth)
        root.right = treeGenerator(X_right,y_right,depth+1,max_depth)
        return root


#每一层的attribute可以重复用，所以每次都要搜索最好的splitter,data only contains binary variables
# and continuous variables,using information entropy as splitting rull
def findBestSplit(X,y):
    min = float('inf')
    selectedAttr = X.columns[0]
    splitter = 0
    for attr in X.columns.values:
        #print(attr)
        X_sort = X.sort_values([attr])
        l = len(X_sort)
        #can do better!!!!!!!
        #TODO: check binary column
        for i in range(1,l):
            left = X_sort.iloc[:i]
            right = X_sort.iloc[i:]
            leftSet = pd.value_counts(y[left.index])
            rightSet = pd.value_counts(y[right.index])
            leftEntropy = 0
            rightEntropy = 0
            sumLeft = sum(leftSet)
            sumRight = sum(rightSet)
            for val in leftSet:
                p = val/sumLeft
                leftEntropy += p * np.log2(p)
            for val in rightSet:
                p = val/sumRight
                rightEntropy += p * np.log2(p)
            Entropy = sumLeft/l * leftEntropy + sumRight/l * rightEntropy
            if Entropy<min:
                min = Entropy
                selectedAttr = attr
                splitter = X_sort.iloc[i][attr]
                X_left = left
                X_right = right
    return X_left, X_right,selectedAttr,splitter

# %%
def validation_curve(path, n_attr, size):
    data = pd.read_csv(path, header=None)
    data = data.drop(range(n_attr, 278), 1)
    data = data.iloc[0:size]
    data_clean = data.replace('?', np.nan)  # replace '?' by NAN
    # randomly shuffle the dataset
    data_shuffle = data.reindex(np.random.permutation(data.index))
    length = len(data_shuffle)
    # partition 1
    data_1 = data_shuffle[:int(length / 3)]
    # partition 2
    data_2 = data_shuffle[int(length / 3):int(2 * length / 3)]
    # partition 3
    data_3 = data_shuffle[int(2 * length / 3):]
    data_train1 = data_1.append(data_2)  # data1 & 2 as training set
    X_train1 = data_train1.iloc[:, :-1].copy()
    y_train1 = data_train1.iloc[:, -1].copy()
    X_test1 = data_3.iloc[:, :-1].copy()
    y_test1 = data_3.iloc[:, -1].copy()
    data_train2 = data_1.append(data_3)  # data 1 & 3 as training set
    X_train2 = data_train2.iloc[:, :-1].copy()
    y_train2 = data_train2.iloc[:, -1].copy()
    X_test2 = data_2.iloc[:, :-1].copy()
    y_test2 = data_2.iloc[:, -1].copy()
    data_train3 = data_2.append(data_3)  # data 2 & 3 as training set
    X_train3 = data_train3.iloc[:, :-1].copy()
    y_train3 = data_train3.iloc[:, -1].copy()
    X_test3 = data_1.iloc[:, :-1].copy()
    y_test3 = data_1.iloc[:, -1].copy()
    testAcc = []
    trainAcc = []
    for i in range(2, 21, 2):  # use different max depth
        #print(i)
        testavgacc = 0
        trainavgacc = 0
        dtree1 = DecisionTree(i)
        dtree1.fit(X_train1, y_train1)
        dtree1.printTree()
        y_train_pred1 = dtree1.predict(X_train1)
        y_test_pred1 = dtree1.predict(X_test1)
        # TODO: calculate the accuracy of tree1
        testavgacc += computeAccuracy(y_test_pred1, y_test1)
        trainavgacc += computeAccuracy(y_train_pred1,y_train1)
        dtree2 = DecisionTree(i)
        dtree2.fit(X_train2, y_train2)
        dtree2.printTree()
        y_train_pred2 = dtree2.predict(X_train2)
        y_test_pred2 = dtree2.predict(X_test2)
        # TODO: calculate the accuracy of tree2
        testavgacc += computeAccuracy(y_test_pred2, y_test2)
        trainavgacc += computeAccuracy(y_train_pred2,y_train2)
        dtree3 = DecisionTree(i)
        dtree3.fit(X_train3, y_train3)
        dtree3.printTree()
        y_train_pred3 = dtree3.predict(X_train3)
        y_test_pred3 = dtree3.predict(X_test3)
        # TODO: calculate the accuracy of tree3
        testavgacc += computeAccuracy(y_test_pred3, y_test3)
        trainavgacc += computeAccuracy(y_train_pred3,y_train3)
        testavgacc /= 3
        testAcc.append(testavgacc)
        trainavgacc /= 3
        trainAcc.append(trainavgacc)

    # plot cvAcc
    plt.plot(range(2, 21, 2), testAcc)
    plt.plot(range(2, 21, 2), trainAcc)
    plt.legend(['Testing Accuracy', 'Training accuracy'], loc = 'best')
    plt.savefig('hw1_validation_curve.png')
    plt.show()
    plt.close()
    
def computeAccuracy(pred, real):
    a = 0
    l = len(real)
    for i in range(l):
        if (pred[i] == real.iloc[i]):
            a = a + 1
    return a / l

# %%
validation_curve("arrhythmia.csv",10,50)
# Out:
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: leaf
# class: 1
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<1.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<155.0?
# depth: 5
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 2<153.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<153.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<0.0?
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 1<1.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<1.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<155.0?
# depth: 5
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 2<153.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<153.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 1<1.0?
# depth: 7
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<0.0?
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 1<1.0?
# depth: 6
# type: internal
# column 2<159.0?
# depth: 6
# type: leaf
# class: 1
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<1.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<155.0?
# depth: 5
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 1<1.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 2<153.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<153.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 1<1.0?
# depth: 7
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: internal
# column 1<1.0?
# depth: 9
# type: internal
# column 3<54.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<0.0?
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 1<1.0?
# depth: 6
# type: internal
# column 2<159.0?
# depth: 6
# type: leaf
# class: 1
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 2<160.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 10
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<1.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<155.0?
# depth: 5
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 1<1.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 5<128.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<1.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: leaf
# class: 6
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 2<153.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<153.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 1<1.0?
# depth: 7
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: internal
# column 1<1.0?
# depth: 9
# type: internal
# column 3<54.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 3<55.0?
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<0.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<0.0?
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 1<1.0?
# depth: 6
# type: internal
# column 2<159.0?
# depth: 6
# type: leaf
# class: 1
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 2<160.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 10
# type: internal
# column 4<75.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 5<128.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<1.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<155.0?
# depth: 5
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 1<1.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 5<128.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<1.0?
# depth: 12
# type: internal
# column 3<51.0?
# depth: 12
# type: internal
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 1<1.0?
# depth: 13
# type: leaf
# class: 10
# depth: 13
# type: internal
# depth: 14
# type: leaf
# class: 10
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 6
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 2<153.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<153.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 1<1.0?
# depth: 7
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: internal
# column 1<1.0?
# depth: 9
# type: internal
# column 3<54.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 3<55.0?
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<0.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: internal
# column 4<73.0?
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 4<103.0?
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<0.0?
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 1<1.0?
# depth: 6
# type: internal
# column 2<159.0?
# depth: 6
# type: leaf
# class: 1
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 2<160.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 10
# type: internal
# column 4<75.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 5<128.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: internal
# column 2<160.0?
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 1<1.0?
# depth: 14
# type: leaf
# class: 6
# depth: 14
# type: leaf
# class: 10
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<1.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<155.0?
# depth: 5
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 1<1.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 5<128.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<1.0?
# depth: 12
# type: internal
# column 3<51.0?
# depth: 12
# type: internal
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 1<1.0?
# depth: 13
# type: leaf
# class: 10
# depth: 13
# type: internal
# depth: 14
# type: internal
# column 1<1.0?
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 6
# depth: 15
# type: internal
# column 1<1.0?
# depth: 15
# type: leaf
# class: 10
# depth: 16
# type: leaf
# class: 1
# depth: 16
# type: leaf
# class: 6
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 2<153.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<153.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 1<1.0?
# depth: 7
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: internal
# column 1<1.0?
# depth: 9
# type: internal
# column 3<54.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 3<55.0?
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<0.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: internal
# column 4<73.0?
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 4<103.0?
# depth: 14
# type: internal
# column 3<94.0?
# depth: 14
# type: leaf
# class: 1
# depth: 15
# type: internal
# column 5<145.0?
# depth: 15
# type: leaf
# class: 1
# depth: 16
# type: leaf
# class: 1
# depth: 16
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<0.0?
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 1<1.0?
# depth: 6
# type: internal
# column 2<159.0?
# depth: 6
# type: leaf
# class: 1
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 2<160.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 10
# type: internal
# column 4<75.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 5<128.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: internal
# column 2<160.0?
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 1<1.0?
# depth: 14
# type: internal
# column 5<202.0?
# depth: 14
# type: leaf
# class: 10
# depth: 15
# type: internal
# column 8<60.0?
# depth: 15
# type: leaf
# class: 1
# depth: 16
# type: leaf
# class: 6
# depth: 16
# type: leaf
# class: 10
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<1.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<155.0?
# depth: 5
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 1<1.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 5<128.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<1.0?
# depth: 12
# type: internal
# column 3<51.0?
# depth: 12
# type: internal
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 1<1.0?
# depth: 13
# type: leaf
# class: 10
# depth: 13
# type: internal
# depth: 14
# type: internal
# column 1<1.0?
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 6
# depth: 15
# type: internal
# column 1<1.0?
# depth: 15
# type: leaf
# class: 10
# depth: 16
# type: internal
# column 5<181.0?
# depth: 16
# type: leaf
# class: 6
# depth: 17
# type: internal
# column 3<95.0?
# depth: 17
# type: internal
# depth: 18
# type: leaf
# class: 1
# depth: 18
# type: leaf
# class: 10
# depth: 18
# type: leaf
# class: 10
# depth: 18
# type: leaf
# class: 1
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 2<153.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<153.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 1<1.0?
# depth: 7
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: internal
# column 1<1.0?
# depth: 9
# type: internal
# column 3<54.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 3<55.0?
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<0.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: internal
# column 4<73.0?
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 4<103.0?
# depth: 14
# type: internal
# column 3<94.0?
# depth: 14
# type: leaf
# class: 1
# depth: 15
# type: internal
# column 5<145.0?
# depth: 15
# type: leaf
# class: 1
# depth: 16
# type: leaf
# class: 1
# depth: 16
# type: internal
# column 3<88.0?
# depth: 17
# type: internal
# column 1<1.0?
# depth: 17
# type: internal
# depth: 18
# type: leaf
# class: 1
# depth: 18
# type: leaf
# class: 1
# depth: 18
# type: leaf
# class: 10
# depth: 18
# type: leaf
# class: 1
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<0.0?
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 1<1.0?
# depth: 6
# type: internal
# column 2<159.0?
# depth: 6
# type: leaf
# class: 1
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 2<160.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 10
# type: internal
# column 4<75.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 5<128.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: internal
# column 2<160.0?
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 1<1.0?
# depth: 14
# type: internal
# column 5<202.0?
# depth: 14
# type: leaf
# class: 10
# depth: 15
# type: internal
# column 8<60.0?
# depth: 15
# type: leaf
# class: 1
# depth: 16
# type: leaf
# class: 6
# depth: 16
# type: internal
# column 1<1.0?
# depth: 17
# type: internal
# column 3<95.0?
# depth: 17
# type: leaf
# class: 1
# depth: 18
# type: leaf
# class: 6
# depth: 18
# type: leaf
# class: 10
# depth: 0
# type: internal
# column 2<153.0?
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# column 1<1.0?
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<1.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<155.0?
# depth: 5
# type: leaf
# class: 1
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 1<1.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 5<128.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<1.0?
# depth: 12
# type: internal
# column 3<51.0?
# depth: 12
# type: internal
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 1<1.0?
# depth: 13
# type: leaf
# class: 10
# depth: 13
# type: internal
# depth: 14
# type: internal
# column 1<1.0?
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 1
# depth: 14
# type: leaf
# class: 6
# depth: 15
# type: internal
# column 1<1.0?
# depth: 15
# type: leaf
# class: 10
# depth: 16
# type: internal
# column 5<181.0?
# depth: 16
# type: leaf
# class: 6
# depth: 17
# type: internal
# column 3<95.0?
# depth: 17
# type: internal
# depth: 18
# type: internal
# column 3<85.0?
# depth: 18
# type: leaf
# class: 10
# depth: 18
# type: leaf
# class: 10
# depth: 18
# type: leaf
# class: 1
# depth: 19
# type: internal
# depth: 19
# type: leaf
# class: 6
# depth: 20
# type: leaf
# class: 14
# depth: 20
# type: leaf
# class: 1
# depth: 0
# type: internal
# depth: 1
# type: leaf
# class: 1
# depth: 1
# type: internal
# depth: 2
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 3
# type: internal
# column 1<1.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 2<153.0?
# depth: 4
# type: leaf
# class: 1
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 2<153.0?
# depth: 6
# type: leaf
# class: 1
# depth: 6
# type: internal
# column 1<1.0?
# depth: 7
# type: internal
# column 2<156.0?
# depth: 7
# type: leaf
# class: 1
# depth: 8
# type: leaf
# class: 1
# depth: 8
# type: internal
# column 1<1.0?
# depth: 9
# type: internal
# column 3<54.0?
# depth: 9
# type: leaf
# class: 1
# depth: 10
# type: leaf
# class: 1
# depth: 10
# type: internal
# column 3<55.0?
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 1<0.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: internal
# column 4<73.0?
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 4<103.0?
# depth: 14
# type: internal
# column 3<94.0?
# depth: 14
# type: leaf
# class: 1
# depth: 15
# type: internal
# column 5<145.0?
# depth: 15
# type: leaf
# class: 1
# depth: 16
# type: leaf
# class: 1
# depth: 16
# type: internal
# column 3<88.0?
# depth: 17
# type: internal
# column 1<1.0?
# depth: 17
# type: internal
# depth: 18
# type: internal
# column 1<1.0?
# depth: 18
# type: leaf
# class: 1
# depth: 18
# type: leaf
# class: 10
# depth: 18
# type: leaf
# class: 1
# depth: 19
# type: internal
# depth: 19
# type: leaf
# class: 1
# depth: 20
# type: leaf
# class: 10
# depth: 20
# type: leaf
# class: 4
# depth: 0
# type: internal
# column 1<1.0?
# depth: 1
# type: internal
# column 1<1.0?
# depth: 1
# type: leaf
# class: 1
# depth: 2
# type: internal
# column 1<1.0?
# depth: 2
# type: leaf
# class: 1
# depth: 3
# type: internal
# column 2<155.0?
# depth: 3
# type: leaf
# class: 1
# depth: 4
# type: leaf
# class: 1
# depth: 4
# type: internal
# column 1<0.0?
# depth: 5
# type: leaf
# class: 1
# depth: 5
# type: internal
# column 1<1.0?
# depth: 6
# type: internal
# column 2<159.0?
# depth: 6
# type: leaf
# class: 1
# depth: 7
# type: leaf
# class: 1
# depth: 7
# type: internal
# column 1<1.0?
# depth: 8
# type: internal
# column 2<160.0?
# depth: 8
# type: leaf
# class: 1
# depth: 9
# type: leaf
# class: 1
# depth: 9
# type: internal
# column 1<1.0?
# depth: 10
# type: internal
# column 4<75.0?
# depth: 10
# type: leaf
# class: 1
# depth: 11
# type: leaf
# class: 1
# depth: 11
# type: internal
# column 5<128.0?
# depth: 12
# type: leaf
# class: 1
# depth: 12
# type: internal
# column 2<160.0?
# depth: 13
# type: leaf
# class: 1
# depth: 13
# type: internal
# column 1<1.0?
# depth: 14
# type: internal
# column 5<202.0?
# depth: 14
# type: leaf
# class: 10
# depth: 15
# type: internal
# column 8<60.0?
# depth: 15
# type: leaf
# class: 1
# depth: 16
# type: leaf
# class: 6
# depth: 16
# type: internal
# column 1<1.0?
# depth: 17
# type: internal
# column 3<95.0?
# depth: 17
# type: leaf
# class: 1
# depth: 18
# type: internal
# column 3<85.0?
# depth: 18
# type: leaf
# class: 10
# depth: 19
# type: internal
# depth: 19
# type: leaf
# class: 6
# depth: 20
# type: leaf
# class: 14
# depth: 20
# type: leaf
# class: 10

# %%
data = pd.read_csv("arrhythmia.csv", header=None)
#Assign Binary values
data = data.drop(range(3, 278), 1)
data = data.iloc[0:10]
data_clean = data.replace('?', np.nan)  # replace '?' by NAN
# randomly shuffle the dataset
data_shuffle = data_clean.reindex(np.random.permutation(data_clean.index))
length = len(data_shuffle)

# %%
data_shuffle
# Out:
#    0    1    2     278  279
# 9   50    1  167  25.1   10
# 3   55    0  175  61.6    1
# 5   13    0  169  31.1   14
# 4   75    0  190  62.8    7
# 6   40    1  160  20.5    1
# 8   44    0  168  30.9    1
# 0   75    0  190  49.4    8
# 2   54    0  172  49.0   10
# 7   49    1  162  19.8    1
# 1   56    1  165  38.8    6

# %%
data_1 = data_shuffle[:int(length / 3)]

# %%
data_1
# Out:
#    0    1    2     278  279
# 9   50    1  167  25.1   10
# 3   55    0  175  61.6    1
# 5   13    0  169  31.1   14

# %%
data_2 = data_shuffle[int(length / 3):int(2 * length / 3)]

# %%
data_train1 = data_1.append(data_2)  # data1 & 2 as training set
X_train1 = data_train1.iloc[:, :-1].copy()
y_train1 = data_train1.iloc[:, -1].copy()

# %%
X_train1
# Out:
#    0    1    2     278
# 9   50    1  167  25.1
# 3   55    0  175  61.6
# 5   13    0  169  31.1
# 4   75    0  190  62.8
# 6   40    1  160  20.5
# 8   44    0  168  30.9

# %%
set_values(X_train1.iloc[3][1],'?')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-595-33eed5ca3f1f> in <module>()
# ----> 1 set_values(X_train1.iloc[3][1],'?')
#
# NameError: name 'set_values' is not defined

# %%
X_train1
# Out:
#    0    1    2     278
# 9   50    1  167  25.1
# 3   55    0  175  61.6
# 5   13    0  169  31.1
# 4   75    0  190  62.8
# 6   40    1  160  20.5
# 8   44    0  168  30.9
